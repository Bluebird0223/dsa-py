# %% [markdown]
# # Sorting Algorithms
#
# ## Objectives
# - Master advanced sorting algorithms: Merge Sort and Quick Sort
# - Understand the trade-offs between different sorting techniques
# - Learn to use custom comparators for complex data
# - Solve 10 practice problems
#
# ---

# %% [markdown]
# ## 1. Why Sorting Matters
#
# Sorting is one of the most fundamental operations in computer science. Many algorithms (like Binary Search) require sorted data to function efficiently. Sorting is often a preprocessing step for more complex problems.
#
# ### Stability in Sorting
# A sorting algorithm is **stable** if it preserves the relative order of elements with equal keys.

# %% [markdown]
# ## 2. Merge Sort (Divide and Conquer)
#
# Merge Sort is a stable, divide-and-conquer algorithm with a guaranteed time complexity of O(n log n).

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
            
    result.extend(left[i:])
    result.extend(right[j:])
    return result

# Test implementation
arr = [38, 27, 43, 3, 9, 82, 10]
print(f"Merge Sort Result: {merge_sort(arr)}")

# %% [markdown]
# ## 3. Quick Sort (Divide and Conquer)
#
# Quick Sort is an efficient, in-place sorting algorithm. Although its worst-case is O(n²), its average-case performance is O(n log n) and it's often faster in practice than Merge Sort due to lower constant factors.

# %%
def quick_sort(arr, low=0, high=None):
    if high is None:
        high = len(arr) - 1
        
    if low < high:
        pivot_idx = partition(arr, low, high)
        quick_sort(arr, low, pivot_idx - 1)
        quick_sort(arr, pivot_idx + 1, high)
    return arr

def partition(arr, low, high):
    # Using the last element as pivot (Lomuto partition scheme)
    pivot = arr[high]
    i = low - 1
    
    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
            
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

# Test implementation
arr = [10, 7, 8, 9, 1, 5]
print(f"Quick Sort Result: {quick_sort(arr)}")

# %% [markdown]
# ## 4. Custom Comparators
#
# In Python, we use the `key` parameter in `sorted()` or `.sort()` for custom sorting logic.

# %%
# Sorting objects by attribute
students = [
    {"name": "Alice", "score": 88},
    {"name": "Bob", "score": 95},
    {"name": "Charlie", "score": 88}
]

# Sort by score (descending), then by name (ascending)
sorted_students = sorted(students, key=lambda x: (-x['score'], x['name']))
print(f"Custom Sorted: {sorted_students}")

# %% [markdown]
# ---
#
# # 🏋️ Practice Problems (10 Problems)

# %% [markdown]
# ### Problem 1: Kth Largest Element
# Find the kth largest element in an unsorted array.
# **Hint**: You can sort the array or use a Heap (more efficient).

# %%
def find_kth_largest(nums, k):
    # YOUR CODE HERE
    pass

print(find_kth_largest([3, 2, 3, 1, 2, 4, 5, 5, 6], 4)) # 4

# %% [markdown]
# ### Problem 2: Sort Colors
# Given an array with n objects colored red, white, or blue (0, 1, 2), sort them in-place.
# **Constraint**: Use O(1) extra space.

# %%
def sort_colors(nums):
    # YOUR CODE HERE
    pass

arr = [2, 0, 2, 1, 1, 0]
sort_colors(arr)
print(arr) # [0, 0, 1, 1, 2, 2]

# %% [markdown]
# ### Problem 3: Merge Intervals
# Merge all overlapping intervals.
# **Example**: `[[1,3],[2,6],[8,10]]` → `[[1,6],[8,10]]`

# %%
def merge_intervals(intervals):
    # YOUR CODE HERE
    pass

print(merge_intervals([[1,3],[2,6],[8,10],[15,18]])) # [[1,6],[8,10],[15,18]]

# %% [markdown]
# ### Problem 4-10 Checklist
# - [ ] Largest Number (Form the largest number from a list of integers)
# - [ ] Sort List (Sort a linked list in O(n log n) time)
# - [ ] Insertion Sort List
# - [ ] H-Index
# - [ ] Sorting Sentences
# - [ ] Intersection of Two Arrays
# - [ ] Valid Anagram (Sorting approach)
