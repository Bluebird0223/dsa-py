# %% [markdown]
# # Two Pointers and Sliding Window
#
# ## Objectives
# - Master the Two Pointers (Opposite and Same Direction) strategy
# - Understand the Sliding Window technique (Fixed and Variable)
# - Learn to reduce O(n²) problems to O(n) or O(n log n)
# - Solve 15 curated pointer problems
#
# ---

# %% [markdown]
# ## 1. Two Pointers (Opposite Direction)
#
# This is common on sorted arrays where we move pointers inwards.

# %%
def two_sum_sorted(nums, target):
    left, right = 0, len(nums) - 1
    
    while left < right:
        current_sum = nums[left] + nums[right]
        if current_sum == target:
            return [left + 1, right + 1]
        elif current_sum < target:
            left += 1
        else:
            right -= 1
    return []

print(f"Two Sum Sorted [2,7,11,15], 9: {two_sum_sorted([2,7,11,15], 9)}") # [1, 2]

# %% [markdown]
# ## 2. Sliding Window (Variable Size)
#
# Used to find the longest/shortest subarray satisfying a condition.

# %%
def longest_substring_without_repeats(s):
    char_set = set()
    l = 0
    res = 0
    
    for r in range(len(s)):
        while s[r] in char_set:
            char_set.remove(s[l])
            l += 1
        char_set.add(s[r])
        res = max(res, r - l + 1)
        
    return res

print(f"LUS 'abcabcbb': {longest_substring_without_repeats('abcabcbb')}") # 3

# %% [markdown]
# ---
#
# # 🏋️ Practice Problems (15 Problems)

# %% [markdown]
# ### Problem 1: Container With Most Water
# Find two lines that together with the x-axis forms a container, such that the container contains the most water.

# %%
def max_area(height):
    # YOUR CODE HERE
    pass

# %% [markdown]
# ### Problem 2: 3Sum
# Find all unique triplets in the array which gives the sum of zero.

# %%
def three_sum(nums):
    # YOUR CODE HERE
    pass

# %% [markdown]
# ### Problem 3-15 Checklist
# - [ ] Remove Element
# - [ ] Valid Palindrome
# - [ ] 4Sum
# - [ ] Trapping Rain Water (Two Pointers approach)
# - [ ] Minimum Size Subarray Sum
# - [ ] Permutation in String (Sliding Window)
# - [ ] Longest Repeating Character Replacement
# - [ ] Minimum Window Substring
# - [ ] Max Consecutive Ones III
# - [ ] Squares of a Sorted Array
# - [ ] Backspace String Compare
# - [ ] 3Sum Closest
# - [ ] Is Subsequence
