# %% [markdown]
# # Arrays and Strings
#
# ## 🎯 Objectives
# - Master array manipulation techniques
# - Learn string processing patterns
# - Apply two pointers technique
# - Solve 20 problems from easy to medium
#
# ---

# %% [markdown]
# ## Array Fundamentals
#
# Arrays are the most fundamental data structure. Understanding array operations is crucial for DSA.

# %%
# Array operations time complexity
arr = [1, 2, 3, 4, 5]

# Access by index: O(1)
print(arr[2])  # 3

# Append to end: O(1) amortized
arr.append(6)

# Insert at beginning: O(n) - shifts all elements
arr.insert(0, 0)

# Remove from end: O(1)
arr.pop()

# Remove from beginning: O(n)
arr.pop(0)

# Search: O(n)
print(3 in arr)

# Sort: O(n log n)
arr.sort()
# Out:
# 3
# True

# %% [markdown]
# ## Two Pointers Technique
#
# A powerful pattern for array problems. Use two pointers moving in opposite directions or at different speeds.

# %%
# Example: Reverse an array in-place
def reverse_array(arr):
    left, right = 0, len(arr) - 1
    while left < right:
        arr[left], arr[right] = arr[right], arr[left]
        left += 1
        right -= 1
    return arr

# Time: O(n), Space: O(1)
print(reverse_array([1, 2, 3, 4, 5]))  # [5, 4, 3, 2, 1]

# %% [markdown]
# ## String Operations

# %%
# Strings are IMMUTABLE in Python
s = "hello"
# s[0] = 'H'  # ERROR!

# To modify, convert to list
chars = list(s)
chars[0] = 'H'
s = ''.join(chars)
print(s)  # "Hello"

# Common patterns
s = "  hello world  "
print(s.strip())       # Remove whitespace
print(s.split())       # Split into words
print('_'.join(['a','b','c']))  # Join with separator
# Out:
# Hello
# hello world
# ['hello', 'world']
# a_b_c

# %% [markdown]
# ---
#
# # 🏋️ Practice Problems

# %% [markdown]
# ## Problem 1: Remove Duplicates from Sorted Array (Easy)
#
# Remove duplicates in-place and return the new length.
#
# ```
# Input: nums = [1,1,2]
# Output: 2, nums = [1,2,_]
# ```

# %%
def remove_duplicates(nums):
    """
    Hint: Use two pointers - one for reading, one for writing
    """
    # YOUR CODE HERE
    if not nums:
       return 0
    write=1
    for read in range(1,len(nums)):
        if nums[read] !=nums[read-1]:
            nums[write]=nums[read]
            write+=1
    return write

    pass

nums = [1,1,2,2,3]
k = remove_duplicates(nums)
print(f"Length: {k}, Array: {nums[:k]}")
# Out:
# Length: 3, Array: [1, 2, 3]

# %%
# SOLUTION
def remove_duplicates_solution(nums):
    if not nums:
        return 0
    
    write = 1  # Position to write next unique element
    
    for read in range(1, len(nums)):
        if nums[read] != nums[read - 1]:
            nums[write] = nums[read]
            write += 1
    
    return write

# Time: O(n), Space: O(1)

# %% [markdown]
# ## Problem 2: Move Zeroes (Easy)
#
# Move all zeros to the end while maintaining relative order.
#
# ```
# Input: [0,1,0,3,12]
# Output: [1,3,12,0,0]
# ```

# %%
def move_zeroes(nums):
    # YOUR CODE HERE
    if not nums:
        return 0

    sorted_arr = nums.sort()
    write = 0

    for i in range(len(nums)):
        print(sorted_arr[i])
    #     print(read)
        # if sorted_arr[read] == 0:
        #     sorted_arr.pop(read)
        # else:
        #     sorted_arr.append()

    print(nums)
    pass


nums = [0, 1, 0, 3, 12]
move_zeroes(nums)
print(nums)  # [1,3,12,0,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 22
#      18     pass
#      21 nums = [0, 1, 0, 3, 12]
# ---> 22 move_zeroes(nums)
#      23 print(nums)  # [1,3,12,0,0]
#
# Cell In[15], line 10, in move_zeroes(nums)
#       7 write = 0
#       9 for i in range(len(nums)):
# ---> 10     print(sorted_arr[i])
#      11 #     print(read)
#      12     # if sorted_arr[read] == 0:
#      13     #     sorted_arr.pop(read)
#      14     # else:
#      15     #     sorted_arr.append()
#      17 print(nums)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# SOLUTION
def move_zeroes_solution(nums):
    write = 0  # Position for next non-zero
    
    # Move all non-zeros forward
    for read in range(len(nums)):
        if nums[read] != 0:
            nums[write] = nums[read]
            write += 1
    
    # Fill rest with zeros
    while write < len(nums):
        nums[write] = 0
        write += 1

# Time: O(n), Space: O(1)

# %% [markdown]
# ## Problem 3: Valid Palindrome (Easy)
#
# Check if a string is a palindrome (ignoring non-alphanumeric characters and case).
#
# ```
# Input: "A man, a plan, a canal: Panama"
# Output: True
# ```

# %%
def is_palindrome(s):
    # YOUR CODE HERE
    pass

print(is_palindrome("A man, a plan, a canal: Panama"))  # True
print(is_palindrome("race a car"))  # False

# %%
# SOLUTION
def is_palindrome_solution(s):
    # Clean and convert to lowercase
    cleaned = ''.join(c.lower() for c in s if c.isalnum())
    
    # Two pointers
    left, right = 0, len(cleaned) - 1
    while left < right:
        if cleaned[left] != cleaned[right]:
            return False
        left += 1
        right -= 1
    
    return True

# Time: O(n), Space: O(n) for cleaned string

# %% [markdown]
# ## Problem 4: Best Time to Buy and Sell Stock (Easy) ⭐
#
# Find maximum profit from one transaction.
#
# ```
# Input: prices = [7,1,5,3,6,4]
# Output: 5  # Buy at 1, sell at 6
# ```

# %%
def max_profit(prices):
    """
    Hint: Track minimum price seen so far
    """
    # YOUR CODE HERE
    pass

print(max_profit([7,1,5,3,6,4]))  # 5

# %%
# SOLUTION
def max_profit_solution(prices):
    if not prices:
        return 0
    
    min_price = float('inf')
    max_profit = 0
    
    for price in prices:
        min_price = min(min_price, price)
        max_profit = max(max_profit, price - min_price)
    
    return max_profit

# Time: O(n), Space: O(1)
# Note: This is a DP problem! We'll revisit it in Module 4

# %% [markdown]
# ## Problem 5: Container With Most Water (Medium)
#
# Find two lines that together with x-axis form a container that holds the most water.
#
# ```
# Input: height = [1,8,6,2,5,4,8,3,7]
# Output: 49  # Lines at index 1 and 8
# ```

# %%
def max_area(height):
    """
    Hint: Two pointers from both ends, move the shorter one
    """
    # YOUR CODE HERE
    pass

print(max_area([1,8,6,2,5,4,8,3,7]))  # 49

# %%
# SOLUTION
def max_area_solution(height):
    left, right = 0, len(height) - 1
    max_area = 0
    
    while left < right:
        # Calculate area
        width = right - left
        current_height = min(height[left], height[right])
        area = width * current_height
        max_area = max(max_area, area)
        
        # Move the pointer with shorter height
        if height[left] < height[right]:
            left += 1
        else:
            right -= 1
    
    return max_area

# Time: O(n), Space: O(1)

# %% [markdown]
# ## Additional Problems (6-20)
#
# Try these on your own:
#
# 6. **Rotate Array** (LeetCode 189) - Medium
# 7. **3Sum** (LeetCode 15) - Medium
# 8. **Trapping Rain Water** (LeetCode 42) - Hard
# 9. **Product of Array Except Self** (LeetCode 238) - Medium
# 10. **Find All Duplicates** (LeetCode 442) - Medium
# 11. **Longest Substring Without Repeating Characters** (LeetCode 3) - Medium
# 12. **Valid Anagram** (LeetCode 242) - Easy
# 13. **Group Anagrams** (LeetCode 49) - Medium
# 14. **Longest Palindromic Substring** (LeetCode 5) - Medium
# 15. **String to Integer (atoi)** (LeetCode 8) - Medium
# 16. **Implement strStr()** (LeetCode 28) - Easy
# 17. **Count and Say** (LeetCode 38) - Medium
# 18. **Sort Colors** (LeetCode 75) - Medium
# 19. **Merge Sorted Array** (LeetCode 88) - Easy
# 20. **Maximum Subarray** (LeetCode 53) - Easy (DP problem!)
#
# Refer to Module 7 for detailed problem lists!

# %% [markdown]
# ---
#
# ## ✅ Checkpoint
#
# Before moving to the next notebook, make sure you can:
# - [ ] Apply two pointers technique confidently
# - [ ] Solve array manipulation problems in O(1) space
# - [ ] Handle string processing efficiently
# - [ ] Solve all 5 core problems independently
#
# **Next**: [02_linked_lists.ipynb](02_linked_lists.ipynb)
