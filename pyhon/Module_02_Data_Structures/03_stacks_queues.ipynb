# %% [markdown]
# # Stacks and Queues
#
# ## Objectives
# - Master Stack and Queue implementations
# - Understand the Monotonic Stack/Queue technique
# - Solve 15 curated Stack and Queue problems
#
# ---

# %% [markdown]
# ## 1. Stacks (LIFO - Last In, First Out)
#
# ### Implementation using Python List

# %%
class Stack:
    def __init__(self):
        self.items = []
        
    def push(self, item):
        self.items.append(item)
        
    def pop(self):
        return self.items.pop() if not self.is_empty() else None
        
    def peek(self):
        return self.items[-1] if not self.is_empty() else None
        
    def is_empty(self):
        return len(self.items) == 0

s = Stack()
s.push(1)
s.push(2)
print(f"Stack Peek: {s.peek()}") # 2
print(f"Stack Pop: {s.pop()}")   # 2

# %% [markdown]
# ## 2. Queues (FIFO - First In, First Out)
#
# ### Implementation using `collections.deque`

# %%
from collections import deque

class Queue:
    def __init__(self):
        self.items = deque()
        
    def enqueue(self, item):
        self.items.append(item)
        
    def dequeue(self):
        return self.items.popleft() if not self.is_empty() else None
        
    def is_empty(self):
        return len(self.items) == 0

q = Queue()
q.enqueue(1)
q.enqueue(2)
print(f"Queue Dequeue: {q.dequeue()}") # 1

# %% [markdown]
# ## 3. Monotonic Stack Technique
#
# A monotonic stack is a stack that maintains its elements in a sorted order (increasing or decreasing).

# %%
def next_greater_element(nums):
    res = [-1] * len(nums)
    stack = [] # Monotonic decreasing stack
    
    for i, num in enumerate(nums):
        while stack and nums[stack[-1]] < num:
            idx = stack.pop()
            res[idx] = num
        stack.append(i)
        
    return res

print(f"Next Greater [2,1,2,4,3]: {next_greater_element([2,1,2,4,3])}") # [4, 2, 4, -1, -1]

# %% [markdown]
# ---
#
# # 🏋️ Practice Problems (15 Problems)

# %% [markdown]
# ### Problem 1: Valid Parentheses
# Given a string containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.

# %%
def is_valid(s):
    # YOUR CODE HERE
    pass

print(is_valid("()[]{}")) # True

# %% [markdown]
# ### Problem 2: Min Stack
# Design a stack that supports push, pop, top, and retrieving the minimum element in constant time.

# %%
class MinStack:
    # YOUR CODE HERE
    pass

# %% [markdown]
# ### Problem 3-15 Checklist
# - [ ] Implement Queue using Stacks
# - [ ] Implement Stack using Queues
# - [ ] Evaluate Reverse Polish Notation
# - [ ] Daily Temperatures (Monotonic Stack)
# - [ ] Largest Rectangle in Histogram
# - [ ] Sliding Window Maximum (Monotonic Queue)
# - [ ] Circular Queue
# - [ ] Task Scheduler
# - [ ] Simplify Path
# - [ ] Asteroid Collision
# - [ ] Decode String
# - [ ] Trapping Rain Water (Stack approach)
# - [ ] Basic Calculator
